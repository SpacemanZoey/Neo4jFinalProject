# %%
import pandas as pd

# %%
filename = 'song_unduplicated.csv'
names = ['albumname','songname','singer','singermid','songmid','tags','tagsid','visitnum','albummid','url']
data = pd.read_csv(filename, names = names, encoding='utf-8')

# %%
data.drop([0], inplace = True)
data.reset_index(drop=True)
# Out:
#                albumname           songname                     singer  \
# 0               2020热曲DJ         带泪的鱼 (DJ版)                        李小豪
# 1              Insomniac      Ring My Bells           Enrique Iglesias
# 2                  我们不一样       最美情侣 (DJ加快版)                        范小松
# 3                  小乒和小乓              小乒和小乓                        于文文
# 4               情深往事直到永远              相思比梦长                        费玉清
# ...                  ...                ...                        ...
# 54199  Finding Neverland  Finding Neverland                      Teske
# 54200                 追梦                 烟火                        吴奇隆
# 54201                 星合                 星合  all at once (オール・アット・ワンス)
# 54202                 执念               年少轻狂                         齐一
# 54203             原创歌曲合集               杏林无花                      双笙,易言
#
#                            singermid         songmid       tags     tagsid  \
# 0                     004dJwRH4WEf1p  000Sp3eY1XAIAU      DJ,开车      14,85
# 1                     004SBLbl1aKeWR  002Aa6p30yS1Qc  R&B,英语,流行    6,167,8
# 2                     002wHEjm0vvEjs  001um0ns4ICC37         DJ         14
# 3                     000poF8D027tPr  002NMqLN0AhY2T   国语,流行,校园   165,6,16
# 4                     0040MELG3TS8OW  000h8hEG2pmWC2         经典        136
# ...                              ...             ...        ...        ...
# 54199                 000tSmAP19fOoN  002mZrCW0nKv9h         英语        167
# 54200                 004MgTMW0cgf0Z  002mpQ3s0aIV0w      经典,国语    136,165
# 54201                 003dhCGr4OczpC  003nXMOp1cfvTB     日语,ACG     169,39
# 54202                 0020IaUo4Vgsjk  004d5c3M3hW2rV   流行,励志,国语  6,125,165
# 54203  001t94rh4OpQn0,0027DTPN23aYCZ  004LL2c427sgmo      古风,治愈    194,116
#
#         visitnum        albummid  \
# 0      101015449  000hXHcA0fGOM3
# 1      144425847  0043QgUT44uzkH
# 2        1900395  0039IFLn2imRF9
# 3        6169595  003UGaCn4KkZ8b
# 4       13849849  003O0rxy1z86JW
# ...          ...             ...
# 54199    4281553  003XEYPH2csocp
# 54200   78344737  003NAU4t2XJ9Zx
# 54201    3395777  0028YSHK3AURvj
# 54202    2016179  004Nyvd8070Fp0
# 54203   36719768  000dQblX4Xho6U
#
#                                                    url
# 0      https://y.qq.com/n/yqq/song/000Sp3eY1XAIAU.html
# 1      https://y.qq.com/n/yqq/song/002Aa6p30yS1Qc.html
# 2      https://y.qq.com/n/yqq/song/001um0ns4ICC37.html
# 3      https://y.qq.com/n/yqq/song/002NMqLN0AhY2T.html
# 4      https://y.qq.com/n/yqq/song/000h8hEG2pmWC2.html
# ...                                                ...
# 54199  https://y.qq.com/n/yqq/song/002mZrCW0nKv9h.html
# 54200  https://y.qq.com/n/yqq/song/002mpQ3s0aIV0w.html
# 54201  https://y.qq.com/n/yqq/song/003nXMOp1cfvTB.html
# 54202  https://y.qq.com/n/yqq/song/004d5c3M3hW2rV.html
# 54203  https://y.qq.com/n/yqq/song/004LL2c427sgmo.html
#
# [54204 rows x 10 columns]

# %%
df1 = data[['songmid','singermid']]
df1.columns = ['songmid','singermid']
df2 = df1['singermid'].str.split(',', expand = True).stack()
df2 = df2.reset_index(level=1,drop=True)
df2.name = 'singermid'
df_new = df1.drop(['singermid'], axis = 1).join(df2)
df_new.reset_index(drop=True)
df_new.to_csv('song_singer.csv', index=False)

# %%
df1 = data[['songmid', 'tagsid']]
df1.columns = ['songmid', 'tagsid']
df2 = df1['tagsid'].str.split(',', expand = True).stack()
df2 = df2.reset_index(level=1,drop=True)
df2.name = 'tagsid'
df_new = df1.drop(['tagsid'], axis = 1).join(df2)
df_new.reset_index(drop=True)
df_new.to_csv('song_tag.csv', index=False)

# %%
df1 = data[['songmid','albummid']]
df1.columns = ['songmid','albummid']
df1.to_csv('song_album.csv', index=False)

# %%
df = pd.read_csv('album.csv',encoding='utf-8')
df
# Out:
#              albummid                albumname
# 0      003V1Vao3OS3sb  余生，请多指教 (2020星光大赏Live版)
# 1      002iScmt2I0LsP   最幸运的幸运 (2020星光大赏Live版)
# 2                 NaN                      NaN
# 3      002Tryw33HIGNP               陈情令 国风音乐专辑
# 4      004OLQfC3d8bqt                诛仙I 电影原声带
# ...               ...                      ...
# 35497  003Z2xPq2HzggA             滚石院线 VOL. II
# 35498  003cNW7R4YBfZJ                我想和你唱 第4期
# 35499  002cpS4v2rKAgY                 一颗滚石的25年
# 35500  001u7WbY1xCdwV           周冰倩中华名人名歌经典珍藏版
# 35501  0003RiJ41I0Rjw                    Amour
#
# [35502 rows x 2 columns]

# %%
df.dropna(axis=0, how='any', inplace=True)
df
# Out:
#              albummid                albumname
# 0      003V1Vao3OS3sb  余生，请多指教 (2020星光大赏Live版)
# 1      002iScmt2I0LsP   最幸运的幸运 (2020星光大赏Live版)
# 3      002Tryw33HIGNP               陈情令 国风音乐专辑
# 4      004OLQfC3d8bqt                诛仙I 电影原声带
# 5      0049shen4F74vJ              两只老虎 电影原声大碟
# ...               ...                      ...
# 35497  003Z2xPq2HzggA             滚石院线 VOL. II
# 35498  003cNW7R4YBfZJ                我想和你唱 第4期
# 35499  002cpS4v2rKAgY                 一颗滚石的25年
# 35500  001u7WbY1xCdwV           周冰倩中华名人名歌经典珍藏版
# 35501  0003RiJ41I0Rjw                    Amour
#
# [35500 rows x 2 columns]

# %%
df.to_csv('album.csv')
